# %% [markdown]
# # Big O Notation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import gamma
# gamma is factorial that can handle floats

# %%
# Title your chart "Big O Notation"
# Label your x axis "Elements"
# Label your y axis "Operations"
# Label your curves or make a legend for the curves
# Use LaTex notation where possible

# Curves to graph
# y=0n+1 and label the curve "O(1)"
# y=log(n) and label the curve "O(log n)"
# y=n and label the curve "O(n)"
# y=n ∗ log(n) and label it "O(n log n)"
# y=n^2 and label it "O(n^2)"
# y=2^n and label it "O(2^n)"
# y=n! and label it "O(n!)"
# y=n^n and label it "O(n^n)"
x = np.arange(0.1,15,0.1)
y1 = [0*n+1 for n in x]
y2 = [np.log(n) for n in x]
y3 = [n for n in x]
y4 = [n * np.log(n) for n in x]
y5 = [n**2 for n in x]
y6 = [2**n for n in x]
y7 = [gamma(n + 1) for n in x]
y8 = [n**n for n in x]

plt.plot(x,y1,c='grey',label="$O(1)$")
plt.plot(x,y2,c='brown',label="$O(log n)$")
plt.plot(x,y3,c='purple',label="$O(n)$")
plt.plot(x,y4,c='blue',label="$O(n log n)$")
plt.plot(x,y5,c='orange',label="$O(n^2)$")
plt.plot(x,y6,c='green',label="$O(2^n)$")
plt.plot(x,y7,c='pink',label="$O(n!)$")
plt.plot(x,y8,c='red',label="$O(n^n)$")

plt.xlim(0,15)
plt.ylim(-1,15)
plt.legend(loc='upper right')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.title('Big O Notation')
plt.show()

# %%
# Bonus Write the code necessary to write your name on a
# chart. Use box letters.

# T
plt.hlines(xmin=1,xmax=6,y=6)
plt.vlines(x=1,ymin=5,ymax=6)
plt.vlines(x=3,ymin=0,ymax=5)
plt.vlines(x=4,ymin=0,ymax=5)
plt.vlines(x=6,ymin=5,ymax=6)
plt.hlines(xmin=1,xmax=3,y=5)
plt.hlines(xmin=4,xmax=6,y=5)
plt.hlines(xmin=3,xmax=4,y=0)

# y
xy1 = [6,7,8]
xy2 = [5,6]
xy3 = [6,6.5,7]
yy1 = [3*n-21 for n in xy1]
yy2 = [3*n-18 for n in xy2]
yy3 = [3,1.5,3]
yy4 = [-3*n+18 for n in xy2]

plt.hlines(xmin=5,xmax=6,y=3)
plt.hlines(xmin=7,xmax=8,y=3)
plt.hlines(xmin=5,xmax=6,y=-3)
plt.plot(xy1,yy1)
plt.plot(xy2,yy2)
plt.plot(xy3,yy3)
plt.plot(xy2,yy4)

# l
plt.vlines(x=9,ymin=0,ymax=6)
plt.vlines(x=10,ymin=0,ymax=6)
plt.hlines(xmin=9,xmax=10,y=0)
plt.hlines(xmin=9,xmax=10,y=6)

# e
xe1 = list(np.arange(12,13.1,0.1))
xe2 = list(np.arange(11,14.1,0.1))
xe3 = list(np.arange(11,14,0.1))
xe4 = list(np.arange(12,12.8,0.1))
xe5 = [12.8,13.9]
ye1 = [(2 + np.sqrt(0.5**2-(n-12.5)**2)) for n in xe1]
ye2 = [(1.5 + np.sqrt(1.5**2-(n-12.5)**2)) for n in xe2]
ye3 = [(1.5 - np.sqrt(1.5**2-(n-12.5)**2)) for n in xe3]
ye4 = [(1.5 - np.sqrt(0.5**2-(n-12.5)**2)) for n in xe4]
ye5 = [1.5 - np.sqrt(0.5**2-(12.8-12.5)**2),1.5 - np.sqrt(1.5**2-(13.9-12.5)**2)]

plt.hlines(xmin=12,xmax=14,y=1.5)
plt.hlines(xmin=12,xmax=13,y=2)
plt.plot(xe1,ye1)
plt.plot(xe2,ye2)
plt.plot(xe3,ye3)
plt.plot(xe4,ye4)
plt.plot(xe5,ye5)

# r
xr1 = np.arange(16,18.1,0.1)
xr2 = np.arange(16,18,0.1)
xr3 = [17.9,18.1]
yr1 = [(1.4 + np.sqrt(1.5**2 - (n - 17)**2)) for n in xr1]
yr2 = [(0.65 + np.sqrt(1.5**2 - (n - 17)**2)) for n in xr2]
yr3 = [0.65 + np.sqrt(1.5**2 - (17.9 - 17)**2),1.4 + np.sqrt(1.5**2 - (18.1 - 17)**2)]

plt.vlines(x=15,ymin=0,ymax=3)
plt.vlines(x=16,ymin=2.5,ymax=3)
plt.vlines(x=16,ymin=0,ymax=1.75)
plt.hlines(xmin=15,xmax=16,y=0)
plt.hlines(xmin=15,xmax=16,y=3)
plt.plot(xr1,yr1)
plt.plot(xr2,yr2)
plt.plot(xr3,yr3)

plt.title("Tyler's Box")
plt.show()
